# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('/home/moe/Pictures/20200327_131607.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (3024, 4032, 3)

# %%
plt.imshow(img)

# %%
#Color conversion
fiximg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fiximg)

# %%
img_gray = cv2.imread('/home/moe/Pictures/20200327_131607.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap='magma')

# %%
plt.imshow(fiximg)

# %%
fiximg.shape
# Out:
# (3024, 4032, 3)

# %%
newimg = cv2.resize(fiximg, (3600, 2500))

# %%
plt.imshow(newimg)

# %%
w_ratio = 0.4
h_ratio = 0.7

# %%
new_img = cv2.resize(fiximg, (0,0), fiximg, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
n_img = cv2.flip(fiximg,0)
plt.imshow(n_img)

# %%
cv2.imwrite('fliped.jpg', n_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fiximg)

# %%
fig = plt.figure(figsize=(4,2))
ax = fig.add_subplot(111)
ax.imshow(fiximg)
