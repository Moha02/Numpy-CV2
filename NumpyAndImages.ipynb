# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
pic = Image.open('/home/moe/Pictures/4f272b83f7a0ff278b750eeb143575c2--oil-paintings-wildlife.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (559, 736, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (559, 736, 3)

# %%
R    G    B
0    1    2

# %%
#Red channel 0 red
plt.imshow(pic_red[:,:,0], cmap='gray')

# %%
#Green
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
#Blue
plt.imshow(pic_red[:,:,2], cmap='gray')

# %%
plt.imshow(pic_red[:,:,0])

# %%
pic_red[:,:,1] = 0
plt.imshow(pic_red[:,:,2])

# %%
plt.imshow(pic_red[:,:,])

# %%
pic_red
# Out:
# array([[[252, 252, 250],
#         [255, 255, 253],
#         [255, 255, 253],
#         ...,
#         [254, 254, 254],
#         [253, 253, 253],
#         [255, 255, 255]],
#
#        [[255, 255, 253],
#         [255, 255, 253],
#         [255, 255, 253],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [255, 255, 255]],
#
#        [[255, 255, 253],
#         [254, 254, 252],
#         [253, 253, 251],
#         ...,
#         [254, 254, 254],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [255, 255, 253],
#         [255, 255, 253],
#         [255, 255, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [255, 255, 253],
#         [254, 255, 253],
#         [254, 255, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [254, 255, 253],
#         [254, 255, 253],
#         [254, 255, 253]]], dtype=uint8)
